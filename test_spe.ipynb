# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import sys
from spe_read.spe_read import SpeReader
from select_button.selectfilesbutton import SelectFilesButton
import matplotlib

# %%
## Set graphing properties

matplotlib.rcParams['font.sans-serif'] = ['Arial'] # Helvetica
plt.rcParams["figure.figsize"] = [16, 7]
plt.rcParams["figure.dpi"] = 600
plt.rcParams['axes.linewidth'] = 1.5

SMALL_SIZE = 16
MEDIUM_SIZE = 18
BIGGER_SIZE = 20

# plt.rcParams['axes.facecolor']='white'
# plt.rcParams['savefig.facecolor']='white'
plt.rc('font', size=SMALL_SIZE)  # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)  # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)  # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)  # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)  # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)  # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
spe_object = SpeReader(file_name="../../Projects/CAREER/Gasket_in_LiF/02102024/Sample_PL-532nm_Pow_400uW-et_0.3sec-avg_5-300_680-loc_1  01.spe")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 spe_object = SpeReader(file_name="../../Projects/CAREER/Gasket_in_LiF/02102024/Sample_PL-532nm_Pow_400uW-et_0.3sec-avg_5-300_680-loc_1  01.spe")
#
# File g:\Shared drives\Pauzauskie Team Drive\Users\CG\Scripts\Data_Analysis\spe_read\spe_read.py:11, in SpeReader.__init__(self, file_name)
#       9 def __init__(self, file_name) -> None:
#      10     self._file_name = file_name
# ---> 11     self.spe_files = sl.load_from_files([self._file_name])
#      12     self.spe_tool = spe.SpeTool(self._file_name)
#      14     self.metadata = self.spe_files.footer
#
# File c:\Users\profe\AppData\Local\Programs\Python\Python310\lib\site-packages\spe_loader.py:223, in load_from_files(filepaths)
#     221 batch = [[] for _ in range(0, len(filepaths))]
#     222 for file in range(0, len(filepaths)):
# ...

# %%
frame_number = 0
roi_number = 0
intensity_data = spe_object.spe_files.data[frame_number][roi_number][0]
wavelength_data = spe_object.metadata.SpeFormat.Calibrations.WavelengthMapping.Wavelength

# %%
print(wavelength_data)
# Out:
# Element <Wavelength> with attributes {}, children [] and cdata 540.08133185458576,540.21139474283439,540.34145766165739,540.47152061042925,540.60158358852425,540.73164659531665,540.86170963018048,540.99177269249026,541.12183578162,541.25189889694423,541.38196203783673,541.512025203672,541.64208839382422,541.7721516076673,541.9022148445755,542.032278103923,542.16234138508389,542.29240468743194,542.42246801034185,542.55253135318731,542.68259471534213,542.81265809618094,542.94272149507742,543.07278491140539,543.20284834453923,543.33291179385265,543.46297525871989,543.59303873851445,543.7231022326107,543.85316574038222,543.98322926120318,544.11329279444737,544.24335633948863,544.37341989570075,544.50348346245789,544.63354703913353,544.76361062510159,544.89367421973589,545.02373782241034,545.15380143249843,545.2838650493743,545.41392867241132,545.5439923009834,545.67405593446426,545.80411957222771,545.9341832136472,546.06424685809645,546.19431050494927,546.32437415357936,546.45443780336,5
# ...

# %%
len(wavelength_data)
# Out:
# 0

# %%
plt.plot(wavelength_data)

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.plot(wavelength_data,intensity_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [9], in <cell line: 3>()
#       1 fig1 = plt.figure()
#       2 ax1 = fig1.add_subplot(111)
# ----> 3 ax1.plot(wavelength_data,intensity_data)
#
# File c:\Users\profe\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1390 """
#    1391 Plot y versus x as lines and/or markers.
#    1392
#    (...)
#    1629 (``'green'``) or hex strings (``'#008000'``).
#    1630 """
#    1631 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
#    1634     self.add_line(line)
#
# ...
